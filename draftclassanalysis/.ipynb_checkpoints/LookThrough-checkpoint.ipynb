# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

from itertools import combinations

# %%
# import data_pull as _
import process_data as _

# %%
def ordinal(n):
    return "%d%s" % (n, "tsnrhtdd"[(n/10 % 10 != 1)*(n % 10 < 4)*n % 10::4])

# %%
df = pd.read_csv('./full_data.csv', index_col='index')

# %%
df.columns
# Out:
# Index(['year', 'PICK', 'TEAM', 'PLAYER', 'YEARS', 'TOTALS_G', 'TOTALS_MP',
#        'final_season', 'ADVANCED_WS', 'ADVANCED_WS/48', 'ADVANCED_BPM',
#        'ADVANCED_VORP', 'MVP_Votes', 'First_MVP', 'RotY_Votes', 'RotY',
#        'DPOY_Votes', 'First_DPOY', 'SMotY_Votes', 'First_SMotY', 'MIP_Votes',
#        'First_MIP', 'all_nba_votes', 'all_defense_votes', 'all_rookie_votes',
#        'all_first', 'all_second', 'all_third', 'all_races', 'def_first',
#        'def_second', 'mvp', 'rookie', 'retired', 'rookie_first',
#        'rookie_second', 'dcn_past_retirement', 'dcn_YEARS', 'dcn_TOTALS_G',
#        'dcn_TOTALS_MP', 'dcn_ADVANCED_WS', 'dcn_ADVANCED_WS/48',
#        'dcn_MVP_Votes', 'dcn_RotY_Votes', 'dcn_DPOY_Votes', 'dcn_SMotY_Votes',
#        'dcn_MIP_Votes', 'dcn_all_nba_votes', 'dcn_all_defense_votes',
#        'dcn_all_rookie_votes', 'pn_past_retirement', 'pn_YEARS', 'pn_TOTALS_G',
#        'pn_TOTALS_MP', 'pn_ADVANCED_WS', 'pn_ADVANCED_WS/48', 'pn_MVP_Votes',
#        'pn_RotY_Votes', 'pn_DPOY_Votes', 'pn_SMotY_Votes', 'pn_MIP_Votes',
#        'pn_all_nba_votes', 'pn_all_defense_votes', 'pn_all_rookie_votes',
#        'pn_YEARS_ma', 'dcn_YEARS_ma', 'pn_TOTALS_G_ma', 'dcn_TOTALS_G_ma',
#        'pn_TOTALS_MP_ma', 'dcn_TOTALS_MP_ma', 'pn_ADVANCED_WS_ma',
#        'dcn_ADVANCED_WS_ma', 'pn_ADVANCED_WS/48_ma', 'dcn_ADVANCED_WS/48_ma',
#        'pn_MVP_Votes_ma', 'dcn_MVP_Votes_ma', 'pn_RotY_Votes_ma',
#        'dcn_RotY_Votes_ma', 'pn_DPOY_Votes_ma', 'dcn_DPOY_Votes_ma',
#        'pn_SMotY_Votes_ma', 'dcn_SMotY_Votes_ma', 'pn_MIP_Votes_ma',
#        'dcn_MIP_Votes_ma', 'pn_all_nba_votes_ma', 'dcn_all_nba_votes_ma',
#        'pn_all_defense_votes_ma', 'dcn_all_defense_votes_ma',
#        'pn_all_rookie_votes_ma', 'dcn_all_rookie_votes_ma', 'rookie_first_ma',
#        'rookie_second_ma', 'dcn_past_retirement_ma', 'pn_past_retirement_ma',
#        'exists'],
#       dtype='object')

# %%
STATS = [
    'YEARS', 'TOTALS_G', 'TOTALS_MP', 'ADVANCED_WS', 'ADVANCED_WS/48', 'MVP_Votes', 'RotY_Votes', 'DPOY_Votes',
    'SMotY_Votes', 'MIP_Votes', 'all_nba_votes', 'all_defense_votes', 'all_rookie_votes', 'past_retirement'
]

# %%
stat_year = dict()
dc_normed_year = dict()
p_normed_year = dict()
dcma_year = dict()
pma_year = dict()
team_aggs = dict()

# %%
for stat in STATS:
    if stat != 'past_retirement':
        stat_year[stat] = df.pivot(index='PICK', columns='year', values=stat)
        if 'Votes' in stat:
            team_aggs[stat] = df.pivot_table(index='TEAM', columns='PICK', values=stat, aggfunc='mean').fillna(0.0)
    dc_normed_year[stat] = df.pivot(index='PICK', columns='year', values='dcn_{}'.format(stat))
    p_normed_year[stat] = df.pivot(index='PICK', columns='year', values='pn_{}'.format(stat))
    dcma_year[stat] = df.pivot(index='PICK', columns='year', values='dcn_{}_ma'.format(stat))
    pma_year[stat] = df.pivot(index='PICK', columns='year', values='pn_{}_ma'.format(stat))
    team_aggs['dcn_{}_p'.format(stat)] = df.pivot_table(index='TEAM', columns='PICK', values='dcn_{}'.format(stat), aggfunc='mean').fillna(0.0)
    team_aggs['pn_{}_p'.format(stat)] = df.pivot_table(index='TEAM', columns='PICK', values='pn_{}'.format(stat), aggfunc='mean').fillna(0.0)
    team_aggs['dcn_{}_dc'.format(stat)] = df.pivot_table(index='TEAM', columns='year', values='dcn_{}'.format(stat), aggfunc='mean').fillna(0.0)
    team_aggs['pn_{}_dc'.format(stat)] = df.pivot_table(index='TEAM', columns='year', values='pn_{}'.format(stat), aggfunc='mean').fillna(0.0)

for stat in [
    'rookie_first', 'rookie_second'
]:
    stat_year[stat] = df.pivot(index='PICK', columns='year', values=stat)
    pma_year[stat] = df.pivot(index='PICK', columns='year', values='{}_ma'.format(stat))

# %%
df
# Out:
#        year  PICK TEAM                PLAYER  YEARS  TOTALS_G  TOTALS_MP  \
# index
# 0      1995     1  GSW             Joe Smith     16    1030.0    27022.0
# 58     1996     1  PHI         Allen Iverson     14     914.0    37584.0
# 116    1997     1  SAS            Tim Duncan     19    1392.0    47368.0
# 173    1998     1  LAC    Michael Olowokandi      9     500.0    13129.0
# 231    1999     1  CHI           Elton Brand     17    1058.0    34910.0
# ...     ...   ...  ...                   ...    ...       ...        ...
# 1357   2017    60  ATL            Alpha Kaba      0       NaN        NaN
# 1417   2018    60  PHI  Kostas Antetokounmpo      3      22.0       87.0
# 1477   2019    60  SAC      Vanja Marinković      0       NaN        NaN
# 1537   2020    60  NOP           Sam Merrill      6     203.0     3581.0
# 1597   2021    60  IND  Georgios Kalaitzakis      1      13.0      213.0
#
#        final_season  ADVANCED_WS  ADVANCED_WS/48  ...  dcn_all_nba_votes_ma  \
# index                                             ...
# 0              2011         60.3           0.107  ...                   NaN
# 58             2010         99.0           0.126  ...                   NaN
# 116            2016        206.4           0.209  ...                   NaN
# 173            2007          2.5           0.009  ...                   NaN
# 231            2016        109.6           0.151  ...              1.780732
# ...             ...          ...             ...  ...                   ...
# 1357           2017          NaN             NaN  ...              0.000000
# 1417           2021         -0.2          -0.098  ...              0.000000
# 1477           2019          NaN             NaN  ...              0.000000
# 1537           2026          9.0           0.121  ...              0.000000
# 1597           2022         -0.1          -0.024  ...              0.000000
#
#        pn_all_defense_votes_ma  dcn_all_defense_votes_ma  \
# index
# 0                          NaN                       NaN
# 58                         NaN                       NaN
# 116                        NaN                       NaN
# 173                        NaN                       NaN
# 231                   0.794302                  1.630789
# ...                        ...                       ...
# 1357                  0.000000                  0.000000
# 1417                  0.000000                  0.000000
# 1477                  0.000000                  0.000000
# 1537                  0.000000                  0.000000
# 1597                  0.000000                  0.000000
#
#        pn_all_rookie_votes_ma  dcn_all_rookie_votes_ma  rookie_first_ma  \
# index
# 0                         NaN                      NaN              NaN
# 58                        NaN                      NaN              NaN
# 116                       NaN                      NaN              NaN
# 173                       NaN                      NaN              NaN
# 231                  0.476310                 1.910157              0.8
# ...                       ...                      ...              ...
# 1357                 0.014286                 0.002404              0.0
# 1417                 0.014286                 0.002404              0.0
# 1477                 0.000000                 0.000000              0.0
# 1537                 0.000000                 0.000000              0.0
# 1597                 0.000000                 0.000000              0.0
#
#        rookie_second_ma  dcn_past_retirement_ma  pn_past_retirement_ma  exists
# index
# 0                   NaN                     NaN                    NaN       1
# 58                  NaN                     NaN                    NaN       1
# 116                 NaN                     NaN                    NaN       1
# 173                 NaN                     NaN                    NaN       1
# 231                 0.2                     1.0                    0.8       1
# ...                 ...                     ...                    ...     ...
# 1357                0.0                     0.2                    0.4       1
# 1417                0.0                     0.2                    0.6       1
# 1477                0.0                     0.2                    0.4       1
# 1537                0.0                     0.4                    0.6       1
# 1597                0.0                     0.2                    0.4       1
#
# [1772 rows x 95 columns]

# %%
df.loc[df['ADVANCED_WS/48'].idxmax(), ['year', 'TEAM', 'PICK', 'PLAYER', 'ADVANCED_WS/48']]
# Out:
# year                       1998
# TEAM                        TOR
# PICK                         47
# PLAYER            Tyson Wheeler
# ADVANCED_WS/48            1.367
# Name: 219, dtype: object

# %%
metric = 'YEARS'

plt.figure(figsize=(12,10))
plt.title('{} at each Pick'.format(metric))

x = df['PICK']
y = df[metric]

z = np.polyfit(x, y, 1)
p = np.poly1d(z)

plt.scatter(x, y, alpha=0.15)
plt.plot(x, p(x), 'r--')
plt.show()

plt.figure(figsize=(12,15))
plt.title('{} Normed by Draft Class at each Pick'.format(metric))

new_df = dc_normed_year[metric]

for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('{} Normed by Pick at each Pick'.format(metric))

new_df = p_normed_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('5 Year Moving average of {} Normed by Draft Class at each Pick'.format(metric))

new_df = dcma_year[metric]

all_x = []
all_y = []
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
    all_x.extend(new_df.index)
    all_y.extend(new_df[col])

all_x = np.array(all_x)
all_y = np.array(all_y)
mask = ~np.isnan(all_y)
all_x = all_x[mask]
all_y = all_y[mask]

coefficients = np.polyfit(all_x, all_y, 1)  # 1 = linear
poly = np.poly1d(coefficients)
x_line = np.linspace(all_x.min(), all_x.max(), 100)
plt.plot(x_line, poly(x_line), 'r--', linewidth=2, label='Best Fit')

plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Pick at each Pick'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('5YMA-PN {} 2004-2014'.format(metric))

new_df = pma_year[metric]
for col in new_df.columns:
    if int(col) > 2004 and int(col) < 2015:
        plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('5YMA-PN {} 2015-2025'.format(metric))

new_df = pma_year[metric]
for col in new_df.columns:
    if int(col) > 2014:
        plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} DCN performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['dcn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('DC-N')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['pn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} DCN performance against mean by Pick'.format(metric))

# new_df = team_aggs['dcn_{}_p'.format(metric)]
# for col in new_df.columns:
#     if col < 31:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('DC-N')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Pick'.format(metric))

# new_df = team_aggs['pn_{}_p'.format(metric)]
# for col in new_df.columns:
#     if col < 31:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# %%
metric = 'ADVANCED_WS'

# plt.figure(figsize=(12,10))
# plt.title('{} at each Pick'.format(metric))

# x = df['PICK']
# y = df[metric]

# z = np.polyfit(x, y, 1)
# p = np.poly1d(z)

# plt.scatter(x, y, alpha=0.15)
# plt.plot(x, p(x), 'r--')
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('{} Normed by Draft Class at each Pick'.format(metric))

# new_df = dc_normed_year[metric]

# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('{} Normed by Pick at each Pick'.format(metric))

# new_df = p_normed_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('5 Year Moving average of {} Normed by Draft Class at each Pick'.format(metric))

new_df = dcma_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('5 Year Moving average of {} Normed by Pick at each Pick'.format(metric))

new_df = pma_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2004-2014'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2004 and int(col) < 2015:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2015-2025'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2014:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} performance against mean by Draft Class'.format(metric))

new_df = team_aggs['dcn_{}_dc'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('DCN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['pn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} DCN performance against mean by Pick'.format(metric))

# new_df = team_aggs['dcn_{}_p'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('DCN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Pick'.format(metric))

# new_df = team_aggs['pn_{}_p'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# %%
metric = 'ADVANCED_WS/48'

plt.figure(figsize=(12,10))
plt.title('{} at each Pick'.format(metric))

x = df['PICK']
y = df[metric]

nan_mask = ~np.isnan(y)
all_x = x[nan_mask]
all_y = y[nan_mask]

coefficients = np.polyfit(all_x, all_y, 1)  # 1 = linear
poly = np.poly1d(coefficients)
x_line = np.linspace(all_x.min(), all_x.max(), 100)
plt.plot(x_line, poly(x_line), 'r--', linewidth=2, label='Best Fit')

plt.scatter(x, y, alpha=0.15)
plt.show()

plt.figure(figsize=(12,10))
plt.title('{} at each Pick (without outliers)'.format(metric))

outliers = ['Tyson Wheeler', 'Mile Ilić']

outlier_mask = ~df['PLAYER'].isin(outliers)

x = df['PICK'][outlier_mask]
y = df[metric][outlier_mask]

nan_mask = ~np.isnan(y)
all_x = x[nan_mask]
all_y = y[nan_mask]

coefficients = np.polyfit(all_x, all_y, 1)  # 1 = linear
poly = np.poly1d(coefficients)
x_line = np.linspace(all_x.min(), all_x.max(), 100)
plt.plot(x_line, poly(x_line), 'r--', linewidth=2, label='Best Fit')

plt.scatter(x, y, alpha=0.15)
plt.show()

plt.figure(figsize=(12,15))
plt.title('{} Normed by Draft Class at each Pick'.format(metric))

new_df = dc_normed_year[metric]

for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('{} Normed by Pick at each Pick'.format(metric))

# new_df = p_normed_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('5 Year Moving average of {} Normed by Draft Class at each Pick'.format(metric))

new_df = dcma_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('5 Year Moving average of {} Normed by Pick at each Pick'.format(metric))

new_df = pma_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('5YMA-PN {} 2004-2014'.format(metric))

new_df = pma_year[metric]
for col in new_df.columns:
    if int(col) > 2004 and int(col) < 2015:
        plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('5YMA-PN {} 2015-2025'.format(metric))

new_df = pma_year[metric]
for col in new_df.columns:
    if int(col) > 2014:
        plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} DCN performance against mean by Draft Class'.format(metric))

new_df = team_aggs['dcn_{}_dc'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('DCN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['pn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} DCN performance against mean by Pick'.format(metric))

new_df = team_aggs['dcn_{}_p'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('DCN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Pick'.format(metric))

# new_df = team_aggs['pn_{}_p'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# %%
metric = 'MVP_Votes'

plt.figure(figsize=(12,10))
plt.title('{} at each Pick'.format(metric))

x = df['PICK']
y = df[metric]

z = np.polyfit(x, y, 1)
p = np.poly1d(z)

plt.scatter(x, y, alpha=0.15)
plt.plot(x, p(x), 'r--')
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('{} Normed by Draft Class at each Pick'.format(metric))

# new_df = dc_normed_year[metric]

# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('{} Normed by Pick at each Pick'.format(metric))

# new_df = p_normed_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Draft Class at each Pick'.format(metric))

# new_df = dcma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Pick at each Pick'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2004-2014'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2004 and int(col) < 2015:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2015-2025'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2014:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['dcn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('DCN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['pn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} DCN performance against mean by Pick'.format(metric))

# new_df = team_aggs['dcn_{}_p'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('DCN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Pick'.format(metric))

# new_df = team_aggs['pn_{}_p'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# %%
metric = 'RotY_Votes'

plt.figure(figsize=(12,10))
plt.title('{} at each Pick'.format(metric))

x = df['PICK']
y = df[metric]

z = np.polyfit(x, y, 1)
p = np.poly1d(z)

plt.scatter(x, y, alpha=0.15)
plt.plot(x, p(x), 'r--')
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('{} Normed by Draft Class at each Pick'.format(metric))

# new_df = dc_normed_year[metric]

# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('{} Normed by Pick at each Pick'.format(metric))

new_df = p_normed_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Draft Class at each Pick'.format(metric))

# new_df = dcma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Pick at each Pick'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2004-2014'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2004 and int(col) < 2015:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2015-2025'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2014:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} performance against mean by Draft Class'.format(metric))

new_df = team_aggs['dcn_{}_dc'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('DCN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['pn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} DCN performance against mean by Pick'.format(metric))

new_df = team_aggs['dcn_{}_p'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('DCN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Pick'.format(metric))

# new_df = team_aggs['pn_{}_p'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# %%
metric = 'DPOY_Votes'

plt.figure(figsize=(12,10))
plt.title('{} at each Pick'.format(metric))

x = df['PICK']
y = df[metric]

z = np.polyfit(x, y, 1)
p = np.poly1d(z)

plt.scatter(x, y, alpha=0.15)
plt.plot(x, p(x), 'r--')
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('{} Normed by Draft Class at each Pick'.format(metric))

# new_df = dc_normed_year[metric]

# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('{} Normed by Pick at each Pick'.format(metric))

new_df = p_normed_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Draft Class at each Pick'.format(metric))

# new_df = dcma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Pick at each Pick'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2004-2014'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2004 and int(col) < 2015:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2015-2025'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2014:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['dcn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('DCN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['pn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} DCN performance against mean by Pick'.format(metric))

# new_df = team_aggs['dcn_{}_p'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('DCN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Pick'.format(metric))

# new_df = team_aggs['pn_{}_p'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# %%
metric = 'SMotY_Votes'

plt.figure(figsize=(12,10))
plt.title('{} at each Pick'.format(metric))

x = df['PICK']
y = df[metric]

z = np.polyfit(x, y, 1)
p = np.poly1d(z)

plt.scatter(x, y, alpha=0.15)
plt.plot(x, p(x), 'r--')
plt.show()

plt.figure(figsize=(12,15))
plt.title('{} Normed by Draft Class at each Pick'.format(metric))

new_df = dc_normed_year[metric]

for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('{} Normed by Pick at each Pick'.format(metric))

new_df = p_normed_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('5 Year Moving average of {} Normed by Draft Class at each Pick'.format(metric))

new_df = dcma_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('5 Year Moving average of {} Normed by Pick at each Pick'.format(metric))

new_df = pma_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('5YMA-PN {} 2004-2014'.format(metric))

new_df = pma_year[metric]
for col in new_df.columns:
    if int(col) > 2004 and int(col) < 2015:
        plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('5YMA-PN {} 2015-2025'.format(metric))

new_df = pma_year[metric]
for col in new_df.columns:
    if int(col) > 2014:
        plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} performance against mean by Draft Class'.format(metric))

new_df = team_aggs['dcn_{}_dc'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('DCN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} PN performance against mean by Draft Class'.format(metric))

new_df = team_aggs['pn_{}_dc'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('PN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} DCN performance against mean by Pick'.format(metric))

new_df = team_aggs['dcn_{}_p'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('DCN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} PN performance against mean by Pick'.format(metric))

new_df = team_aggs['pn_{}_p'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('PN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# %%
metric = 'MIP_Votes'

plt.figure(figsize=(12,10))
plt.title('{} at each Pick'.format(metric))

x = df['PICK']
y = df[metric]

z = np.polyfit(x, y, 1)
p = np.poly1d(z)

plt.scatter(x, y, alpha=0.15)
plt.plot(x, p(x), 'r--')
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('{} Normed by Draft Class at each Pick'.format(metric))

# new_df = dc_normed_year[metric]

# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('{} Normed by Pick at each Pick'.format(metric))

new_df = p_normed_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Draft Class at each Pick'.format(metric))

# new_df = dcma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Pick at each Pick'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2004-2014'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2004 and int(col) < 2015:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2015-2025'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2014:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['dcn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('DCN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['pn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} DCN performance against mean by Pick'.format(metric))

# new_df = team_aggs['dcn_{}_p'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('DCN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Pick'.format(metric))

# new_df = team_aggs['pn_{}_p'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# %%
metric = 'all_nba_votes'

plt.figure(figsize=(12,10))
plt.title('{} at each Pick'.format(metric))

x = df['PICK']
y = df[metric]

z = np.polyfit(x, y, 1)
p = np.poly1d(z)

plt.scatter(x, y, alpha=0.15)
plt.plot(x, p(x), 'r--')
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('{} Normed by Draft Class at each Pick'.format(metric))

# new_df = dc_normed_year[metric]

# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('{} Normed by Pick at each Pick'.format(metric))

new_df = p_normed_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Draft Class at each Pick'.format(metric))

# new_df = dcma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Pick at each Pick'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2004-2014'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2004 and int(col) < 2015:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2015-2025'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2014:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} performance against mean by Draft Class'.format(metric))

new_df = team_aggs['dcn_{}_dc'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('DCN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['pn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} DCN performance against mean by Pick'.format(metric))

# new_df = team_aggs['dcn_{}_p'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('DCN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} PN performance against mean by Pick'.format(metric))

new_df = team_aggs['pn_{}_p'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('PN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# %%
metric = 'all_defense_votes'

plt.figure(figsize=(12,10))
plt.title('{} at each Pick'.format(metric))

x = df['PICK']
y = df[metric]

z = np.polyfit(x, y, 1)
p = np.poly1d(z)

plt.scatter(x, y, alpha=0.15)
plt.plot(x, p(x), 'r--')
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('{} Normed by Draft Class at each Pick'.format(metric))

# new_df = dc_normed_year[metric]

# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('{} Normed by Pick at each Pick'.format(metric))

new_df = p_normed_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Draft Class at each Pick'.format(metric))

# new_df = dcma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Pick at each Pick'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2004-2014'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2004 and int(col) < 2015:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5YMA-PN {} 2015-2025'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     if int(col) > 2014:
#         plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['dcn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('DCN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['pn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} DCN performance against mean by Pick'.format(metric))

# new_df = team_aggs['dcn_{}_p'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('DCN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} PN performance against mean by Pick'.format(metric))

new_df = team_aggs['pn_{}_p'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('PN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# %%
metric = 'all_rookie_votes'

plt.figure(figsize=(12,10))
plt.title('{} at each Pick'.format(metric))

x = df['PICK']
y = df[metric]

z = np.polyfit(x, y, 1)
p = np.poly1d(z)

plt.scatter(x, y, alpha=0.15)
plt.plot(x, p(x), 'r--')
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('{} Normed by Draft Class at each Pick'.format(metric))

# new_df = dc_normed_year[metric]

# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('{} Normed by Pick at each Pick'.format(metric))

new_df = p_normed_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('5 Year Moving average of {} Normed by Draft Class at each Pick'.format(metric))

new_df = dcma_year[metric]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('5 Year Moving average of {} Normed by Pick at each Pick'.format(metric))

# new_df = pma_year[metric]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Pick')
# plt.ylabel(metric)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('5YMA-PN {} 2004-2014'.format(metric))

new_df = pma_year[metric]
for col in new_df.columns:
    if int(col) > 2004 and int(col) < 2015:
        plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('5YMA-PN {} 2015-2025'.format(metric))

new_df = pma_year[metric]
for col in new_df.columns:
    if int(col) > 2014:
        plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Pick')
plt.ylabel(metric)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} DCN performance against mean by Draft Class'.format(metric))

new_df = team_aggs['dcn_{}_dc'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('DCN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Draft Class'.format(metric))

# new_df = team_aggs['pn_{}_dc'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

plt.figure(figsize=(12,15))
plt.title('Team {} DCN performance against mean by Pick'.format(metric))

new_df = team_aggs['dcn_{}_p'.format(metric)]
for col in new_df.columns:
    plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
plt.xlabel('Team')
plt.ylabel('DCN')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout() 
plt.grid(True, alpha=0.3)
plt.show()

# plt.figure(figsize=(12,15))
# plt.title('Team {} PN performance against mean by Pick'.format(metric))

# new_df = team_aggs['pn_{}_p'.format(metric)]
# for col in new_df.columns:
#     plt.scatter(new_df.index, new_df[col], label=col, alpha=0.7)
# plt.xlabel('Team')
# plt.ylabel('PN')
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
# plt.tight_layout() 
# plt.grid(True, alpha=0.3)
# plt.show()

# %%
# Summary

print('General Summary')
print('Number of picks in sample for each pick:')
c = df.PICK.value_counts()
for p in df.PICK.unique():
    print('{}: {}/30'.format(p, c[p]))

print('Number of times each team has picked')
for team in df.TEAM.unique():
    n = df['TEAM'] == team
    a = df['PICK'][(df.PICK < 31) & n]
    print('{}: {} times'.format(team, n.sum()))
    print('Average FRP: {}'.format(a.mean()))
# Out:
# General Summary
# Number of picks in sample for each pick:
# 1: 30/30
# 2: 30/30
# 3: 30/30
# 4: 30/30
# 5: 30/30
# 6: 30/30
# 7: 30/30
# 8: 30/30
# 9: 30/30
# 10: 30/30
# 11: 30/30
# 12: 30/30
# 13: 30/30
# 14: 30/30
# 15: 30/30
# 16: 30/30
# 17: 30/30
# 18: 30/30
# 19: 30/30
# 20: 30/30
# 21: 30/30
# 22: 30/30
# 23: 30/30
# 24: 30/30
# 25: 30/30
# 26: 30/30
# 27: 30/30
# 28: 30/30
# 29: 27/30
# 30: 30/30
# 31: 30/30
# 32: 30/30
# 33: 30/30
# 34: 30/30
# 35: 30/30
# 36: 30/30
# 37: 30/30
# 38: 30/30
# 39: 30/30
# 40: 30/30
# 41: 30/30
# 42: 30/30
# 43: 30/30
# 44: 30/30
# 45: 30/30
# 46: 30/30
# 47: 30/30
# 48: 30/30
# 49: 30/30
# 50: 30/30
# 51: 30/30
# 52: 30/30
# 53: 30/30
# 54: 30/30
# 55: 30/30
# 56: 30/30
# 57: 30/30
# 58: 30/30
# 59: 18/30
# 60: 17/30
# Number of times each team has picked
# GSW: 55 times
# Average FRP: 14.379310344827585
# PHI: 81 times
# Average FRP: 14.1875
# SAS: 64 times
# Average FRP: 21.448275862068964
# LAC: 48 times
# Average FRP: 12.807692307692308
# CHI: 64 times
# Average FRP: 15.36111111111111
# BRK: 53 times
# Average FRP: 18.633333333333333
# WAS: 53 times
# Average FRP: 11.24
# HOU: 56 times
# Average FRP: 16.727272727272727
# CLE: 54 times
# Average FRP: 12.35483870967742
# ORL: 64 times
# Average FRP: 13.36111111111111
# MIL: 62 times
# Average FRP: 13.28
# TOR: 47 times
# Average FRP: 12.464285714285714
# POR: 66 times
# Average FRP: 16.545454545454547
# NOP: 42 times
# Average FRP: 12.052631578947368
# MIN: 69 times
# Average FRP: 12.53125
# PHO: 57 times
# Average FRP: 16.735294117647058
# DET: 63 times
# Average FRP: 14.344827586206897
# ATL: 72 times
# Average FRP: 14.805555555555555
# MEM: 58 times
# Average FRP: 14.818181818181818
# CHA: 59 times
# Average FRP: 12.147058823529411
# OKC: 76 times
# Average FRP: 17.45945945945946
# MIA: 42 times
# Average FRP: 17.555555555555557
# LAL: 53 times
# Average FRP: 19.791666666666668
# SAC: 61 times
# Average FRP: 12.275862068965518
# BOS: 70 times
# Average FRP: 16.666666666666668
# DEN: 54 times
# Average FRP: 17.037037037037038
# UTA: 70 times
# Average FRP: 19.46153846153846
# NYK: 53 times
# Average FRP: 16.75862068965517
# DAL: 50 times
# Average FRP: 17.57894736842105
# IND: 56 times
# Average FRP: 18.03846153846154

# %%
# Playtime Summary

metric = 'YEARS'

print('Playtime summary')

a = df['YEARS'][(df['retired'])].mean()
b = df['TOTALS_G'][(df['retired'])].mean()
c = df['TOTALS_MP'][(df['retired'])].mean()

print('Average career length is: {} years, {} games played, or {} minutes played'.format(a, b, c))

coeffs = dict()
c5 = 0
c7 = 0
c9 = 0
for year in df.year.unique():
    yamask = df['year'] == year
    coeff, p = stats.spearmanr(df.PICK[yamask], df[metric][yamask], nan_policy='omit')
    if p < 0.5:
        coeffs.update({year: coeff})
        a = abs(coeff)
        if a > 0.5:
            c5 += 1
            if a > 0.7:
                c7 += 1
                if a > 0.9:
                    c9 += 1

correlation_vector = pd.Series(coeffs)
l = len(coeffs)
print(f'{l}/30 seasons gave us accurate correlations across {metric}')
if c5 > 0:
    print(f'{c5} of those {l} seasons had coefficients with magnitude over 0.5')
    if c7 > 0:
        print(f'{c7} of those {l} seasons had coefficients with magnitude over 0.7')
        if c9 > 0:
            print(f'{c9} of those {l} seasons had coefficients with magnitude over 0.9')

acc_mask = df['year'].isin(coeffs.keys())

coeff, p = stats.spearmanr(df.PICK[acc_mask], df[metric][acc_mask], nan_policy='omit')

print('The correlation of {} over those accurate seasons: {}'.format(metric, coeff))

for i in range(1,61):
    pick_mask = df['PICK'] == i
    still_playing = pick_mask & ~(df['retired'])
    
    m = df['YEARS'][pick_mask].mean()
    gp = df['TOTALS_G'][pick_mask].mean()
    mp = df['TOTALS_MP'][pick_mask].mean()
    n = (still_playing & (df[metric] > a)).sum()
    o = (still_playing & (df[metric] > m)).sum()
    p = still_playing.sum()
    r = df[pick_mask & (df['retired'])][metric].mean()
    
    print('{} pick: {} years'.format(ordinal(i), m))
    print('{} pick: {} games played'.format(ordinal(i), gp))
    print('{} pick: {} minutes played'.format(ordinal(i), mp))
    print('Average length of career at {} pick: {}'.format(ordinal(i), r))
    print('Players left in the league at {} pick: {}'.format(ordinal(i), p))
    print('Players left in the league at {} pick who have outlasted the average career: {}/{}'.format(ordinal(i), n, p))
    print('Players left in the league at {} pick who have outlasted the average career at that pick: {}/{}'.format(ordinal(i), o, p))
# Out:
# Playtime summary
# Average career length is: 5.423049894588897 years, 336.9718309859155 games played, or 7787.537696768848 minutes played
# 30/30 seasons gave us accurate correlations across YEARS
# 23 of those 30 seasons had coefficients with magnitude over 0.5
# 4 of those 30 seasons had coefficients with magnitude over 0.7
# The correlation of YEARS over those accurate seasons: -0.5784871179972862
# 1st pick: 10.7 years
# 1st pick: 628.4666666666667 games played
# 1st pick: 20169.0 minutes played
# Average length of career at 1st pick: 11.833333333333334
# Players left in the league at 1st pick: 12
# Players left in the league at 1st pick who have outlasted the average career: 12/12
# Players left in the league at 1st pick who have outlasted the average career at that pick: 5/12
# 2nd pick: 9.4 years
# 2nd pick: 553.5 games played
# 2nd pick: 16050.933333333332 minutes played
# Average length of career at 2nd pick: 10.4
# Players left in the league at 2nd pick: 10
# Players left in the league at 2nd pick who have outlasted the average career: 10/10
# Players left in the league at 2nd pick who have outlasted the average career at that pick: 3/10
# 3rd pick: 10.566666666666666 years
# 3rd pick: 655.1666666666666 games played
# 3rd pick: 20230.166666666668 minutes played
# Average length of career at 3rd pick: 12.0
# Players left in the league at 3rd pick: 13
# Players left in the league at 3rd pick who have outlasted the average career: 13/13
# Players left in the league at 3rd pick who have outlasted the average career at that pick: 3/13
# 4th pick: 10.433333333333334 years
# 4th pick: 641.7 games played
# 4th pick: 18813.9 minutes played
# Average length of career at 4th pick: 11.0
# Players left in the league at 4th pick: 12
# Players left in the league at 4th pick who have outlasted the average career: 12/12
# Players left in the league at 4th pick who have outlasted the average career at that pick: 4/12
# 5th pick: 10.833333333333334 years
# 5th pick: 670.3 games played
# 5th pick: 18693.566666666666 minutes played
# Average length of career at 5th pick: 12.578947368421053
# Players left in the league at 5th pick: 11
# Players left in the league at 5th pick who have outlasted the average career: 11/11
# Players left in the league at 5th pick who have outlasted the average career at that pick: 2/11
# 6th pick: 7.533333333333333 years
# 6th pick: 442.56666666666666 games played
# 6th pick: 11869.8 minutes played
# Average length of career at 6th pick: 7.8
# Players left in the league at 6th pick: 10
# Players left in the league at 6th pick who have outlasted the average career: 10/10
# Players left in the league at 6th pick who have outlasted the average career at that pick: 4/10
# 7th pick: 10.366666666666667 years
# 7th pick: 634.9666666666667 games played
# 7th pick: 17780.8 minutes played
# Average length of career at 7th pick: 11.058823529411764
# Players left in the league at 7th pick: 13
# Players left in the league at 7th pick who have outlasted the average career: 13/13
# Players left in the league at 7th pick who have outlasted the average career at that pick: 5/13
# 8th pick: 8.8 years
# 8th pick: 526.1 games played
# 8th pick: 12942.966666666667 minutes played
# Players left in the league at 58th pick who have outlasted the average career: 4/4
# Players left in the league at 58th pick who have outlasted the average career at that pick: 4/4
# 59th pick: 0.5 years
# 59th pick: 16.857142857142858 games played
# 59th pick: 168.28571428571428 minutes played
# Average length of career at 59th pick: 0.5
# Players left in the league at 59th pick: 0
# Players left in the league at 59th pick who have outlasted the average career: 0/0
# Players left in the league at 59th pick who have outlasted the average career at that pick: 0/0
# 60th pick: 2.176470588235294 years
# 60th pick: 126.6 games played
# 60th pick: 2583.1 minutes played
# Average length of career at 60th pick: 1.9375
# Players left in the league at 60th pick: 1
# Players left in the league at 60th pick who have outlasted the average career: 1/1
# Players left in the league at 60th pick who have outlasted the average career at that pick: 1/1

# %%
# Win-Shares Summary
print('Average win shares/48 at each pick')
metric = 'ADVANCED_WS/48'

coeffs = dict()
c5 = 0
c7 = 0
c9 = 0
for year in df.year.unique():
    yamask = df['year'] == year
    coeff, p = stats.spearmanr(df.PICK[yamask], df['pn_{}'.format(metric)][yamask], nan_policy='omit')
    if p < 0.5:
        coeffs.update({year: coeff})
        a = abs(coeff)
        if a > 0.5:
            c5 += 1
            if a > 0.7:
                c7 += 1
                if a > 0.9:
                    c9 += 1

correlation_vector = pd.Series(coeffs)
l = len(coeffs)
print(f'{l}/30 seasons gave us accurate correlations across {metric}')
if c5 > 0:
    print(f'{c5} of those {l} seasons had coefficients with magnitude over 0.5')
    if c7 > 0:
        print(f'{c7} of those {l} seasons had coefficients with magnitude over 0.7')
        if c9 > 0:
            print(f'{c9} of those {l} seasons had coefficients with magnitude over 0.9')

acc_mask = df['year'].isin(coeffs.keys())

coeff, p = stats.spearmanr(df.PICK[acc_mask], df[metric][acc_mask], nan_policy='omit')

print('The correlation of {} over those accurate seasons: {}'.format(metric, coeff))

for i in range(1,61):
    pick_mask = df['PICK'] == i
    past_mask = df['year'] < 2020
    recent_mask = df['year'] > 2019
    nz_mask = df[metric] != 0
    
    m = (df[metric][pick_mask]).mean()
    m2 = (df[metric][pick_mask & nz_mask]).mean()
    m3 = (pick_mask & nz_mask & (df[metric] > m2) & ~(df['retired'])).sum()
    p = (pick_mask & ~(df['retired'])).sum()
    
    print('Average WS/48 at {} pick: {}'.format(ordinal(i), m))
    print('Average non-zero WS/48 at {} pick: {}'.format(ordinal(i), m2))
    print('Players in the league at {} pick beating average WS/48 for their pick: {}/{}'.format(ordinal(i), m3, p))
# Out:
# Average win shares/48 at each pick
# 19/30 seasons gave us accurate correlations across ADVANCED_WS/48
# The correlation of ADVANCED_WS/48 over those accurate seasons: -0.2937286166018687
# Average WS/48 at 1st pick: 0.12169999999999999
# Average non-zero WS/48 at 1st pick: 0.12169999999999999
# Players in the league at 1st pick beating average WS/48 for their pick: 7/12
# Average WS/48 at 2nd pick: 0.09323333333333332
# Average non-zero WS/48 at 2nd pick: 0.09323333333333332
# Players in the league at 2nd pick beating average WS/48 for their pick: 4/10
# Average WS/48 at 3rd pick: 0.11366666666666668
# Average non-zero WS/48 at 3rd pick: 0.11366666666666668
# Players in the league at 3rd pick beating average WS/48 for their pick: 6/13
# Players in the league at 59th pick beating average WS/48 for their pick: 0/0
# Average WS/48 at 60th pick: 0.0274
# Average non-zero WS/48 at 60th pick: 0.0274
# Players in the league at 60th pick beating average WS/48 for their pick: 1/1

# %%
# Voting Summary

vote_masks = {
    'MIP_Votes': (df['MIP_Votes'] != 0),
    'SMotY_Votes': (df['SMotY_Votes'] != 0),
    'DPOY_Votes': (df['DPOY_Votes'] != 0),
    'RotY_Votes': (df['RotY_Votes'] != 0),
    'MVP_Votes': (df['MVP_Votes'] != 0),
    'all_nba_votes': (df['all_nba_votes'] != 0),
    'all_defense_votes': (df['all_defense_votes'] != 0),
    'all_rookie_votes': (df['all_rookie_votes'] != 0),
}

mask_combos = list(combinations(vote_masks.keys(), 2))

for combo in mask_combos:
    c0 = combo[0]
    c1 = combo[1]
    coeff, p = stats.spearmanr(df['dcn_{}'.format(c0)][vote_masks[c0] | vote_masks[c1]], df['dcn_{}'.format(c1)][vote_masks[c0] | vote_masks[c1]], nan_policy='omit')
    print('The correlation between DCN {} and {} is {}'.format(c0, c1, coeff))
# Out:
# The correlation between DCN MIP_Votes and SMotY_Votes is -0.2652617560338338
# The correlation between DCN MIP_Votes and DPOY_Votes is 0.00996924539012184
# The correlation between DCN MIP_Votes and RotY_Votes is -0.3287694549594698
# The correlation between DCN MIP_Votes and MVP_Votes is 0.277616090020904
# The correlation between DCN MIP_Votes and all_nba_votes is 0.3153166164597968
# The correlation between DCN MIP_Votes and all_defense_votes is 0.0181831562973373
# The correlation between DCN MIP_Votes and all_rookie_votes is -0.14413805204659486
# The correlation between DCN SMotY_Votes and DPOY_Votes is -0.6909058475631011
# The correlation between DCN SMotY_Votes and RotY_Votes is -0.6076395837536456
# The correlation between DCN SMotY_Votes and MVP_Votes is -0.5286143624964398
# The correlation between DCN SMotY_Votes and all_nba_votes is -0.5444291194180028
# The correlation between DCN SMotY_Votes and all_defense_votes is -0.5637425542881217
# The correlation between DCN SMotY_Votes and all_rookie_votes is -0.21594575496983337
# The correlation between DCN DPOY_Votes and RotY_Votes is -0.4303330665707576
# The correlation between DCN DPOY_Votes and MVP_Votes is -0.27429239991217463
# The correlation between DCN DPOY_Votes and all_nba_votes is -0.08094392384948428
# The correlation between DCN DPOY_Votes and all_defense_votes is 0.6828007515897817
# The correlation between DCN DPOY_Votes and all_rookie_votes is -0.034468244928735375
# The correlation between DCN RotY_Votes and MVP_Votes is -0.09648079813084424
# The correlation between DCN RotY_Votes and all_nba_votes is -0.012338923805841923
# The correlation between DCN RotY_Votes and all_defense_votes is -0.2813245206500165
# The correlation between DCN RotY_Votes and all_rookie_votes is 0.695560629991107
# The correlation between DCN MVP_Votes and all_nba_votes is 0.7804579336755321
# The correlation between DCN MVP_Votes and all_defense_votes is 0.10013709486928876
# The correlation between DCN MVP_Votes and all_rookie_votes is 0.13719085585610158
# The correlation between DCN all_nba_votes and all_defense_votes is 0.13260658574283574
# The correlation between DCN all_nba_votes and all_rookie_votes is 0.1909684715542458
# The correlation between DCN all_defense_votes and all_rookie_votes is 0.008168071048700164
